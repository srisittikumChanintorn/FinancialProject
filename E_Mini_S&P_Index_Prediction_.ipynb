# %% [markdown]
# # **S&P 500 Index Adj Close Prediction**

# %% [markdown]
# ### Comparative Analysis: Evaluating the S&P Index in Relation to Seven Other Financially Relevant Indices

# %% [markdown]
# # Data Understanding
# <br>

# %% [markdown]
# ## **Index**
# - ### **E-Mini S&P 500**
# #### &nbsp;&nbsp;S&P 500 — ย่อมาจาก Standard and Poor's 500, เป็นดัชนีของตลาดหุ้นของสหรัฐอเมริกา ที่ขึ้นกับมูลค่าตลาดของบริษัท 500 อันดับแรกที่มีหุ้นสามัญจดทะเบียนอยู่ในตลาดหลักทรัพย์นิวยอร์ก หรือ NASDAQ ดัชนี S&P 500 ทำมาเพื่อสะท้อนสถานะของตลาดหุ้นทั้งหมด โดยการติดตามผลตอบแทนและความผันผวนของหุ้นบริษัทขนาดใหญ่ (large cap) 500 อันดับแรกบน NYSE ซึ่งคิดเป็นกว่า 80% ของมูลค่าตลาดทั้งหมด บริษัท 500 แห่ง ประกอบไปด้วย SP500 ทั่วทั้งอุตสาหกรรมหลักทั้งหมด และถูกเลือกตามมูลค่าตลาด สภาพคล่อง ความสามารถในการซื้อขาย และปัจจัยอื่นๆ. การติดตาม S&P 500 เป็นที่นิยมในการวัดและเปรียบเทียบประสิทธิภาพการลงทุนในตลาดหุ้น ซึ่งสถานะของ S&P 500 ถือเป็นตัวบ่งชี้ว่าตลาดหุ้นในสหรัฐอเมริกากำลังเติบโตหรือลดลง นอกจากนี้ยังเป็นตัวบ่งชี้ที่นำมาใช้ในการวิเคราะห์และบริหารการลงทุนในหุ้นและกองทุนรวม
# <br>
# - ### CRUDE OIL FUTURE
# #### &nbsp;&nbsp;สัญญาซื้อขายน้ำมันดิบเบาล่วงหน้า (Light Sweet Crude Oil Futures Contract) เป็นสัญญาซื้อขายที่เกี่ยวข้องกับการซื้อขายน้ำมันดิบประเภทเบาโดยเฉพาะ ซึ่งในทางเทคนิคสัญญาซื้อขายน้ำมันดิบเบาล่วงหน้านี้สามารถใช้เป็นเครื่องมือในการซื้อขายและการลงทุนในตลาดน้ำมันดิบได้  ซึ่งสัญญาซื้อขายน้ำมันดิบเบาล่วงหน้าจะระบุราคาที่ผู้ซื้อจะชำระเมื่อสัญญาเสร็จสิ้นในอนาคต โดยส่วนใหญ่จะมีระยะเวลาที่กำหนดไว้ล่วงหน้า เช่น 1 เดือนหรือ 3 เดือน   การซื้อขายสัญญาซื้อขายน้ำมันดิบเบาล่วงหน้าเกิดขึ้นในตลาดการเงินเช่น ตลาดสินค้าอนุพันธ์ ซึ่งมีสถานที่การซื้อขายที่กำหนดไว้เช่น ตลาดสินค้าดิบแห่งนิวยอร์ก (New York Mercantile Exchange, NYMEX) และตลาดอุตสาหกรรมการซื้อขายสินค้า (Intercontinental Exchange, ICE) เป็นต้น
# <br>
# - ### GOLD FUTURE
# #### &nbsp;&nbsp;Gold Futures (สัญญาซื้อขายทองคำล่วงหน้า) เป็นสัญญาทางการเงินที่เกี่ยวข้องกับการซื้อขายทองคำในอนาคต สัญญาซื้อขายทองคำล่วงหน้านี้ถูกใช้ในตลาดการเงินเพื่อการลงทุนหรือการป้องกันความเสี่ยงทางการเงินที่เกี่ยวข้องกับราคาทองคำ ตลาดทองคำล่วงหน้าสามารถซื้อขายในแพลตฟอร์มการซื้อขายออนไลน์ที่กำหนดไว้เช่น COMEX (Commodity Exchange, Inc.) ในสหรัฐอเมริกา หรือตลาดอื่นๆ ที่มีการซื้อขายสัญญาซื้อขายทองคำล่วงหน้า การซื้อขายสัญญาซื้อขายทองคำล่วงหน้าเป็นวิธีหนึ่งในการลงทุนในทองคำ ผู้ลงทุนสามารถใช้สัญญาซื้อขายทองคำล่วงหน้าเพื่อดำเนินการซื้อหรือขายทองคำโดยไม่ต้องมีการถือทองคำสัมมนา นอกจากนี้สัญญาซื้อขายทองคำล่วงหน้ายังสามารถใช้เป็นเครื่องมือในการป้องกันความเสี่ยงทางการเงินที่เกี่ยวข้องกับราคาทองคำในอนาคต
# <br>
# - ### CBOE 10 YR TREASURY NOTE YIELD
# #### &nbsp;&nbsp;TNX เป็นรหัสสัญญาซื้อขายแลกเปลี่ยน (ticker symbol) สำหรับสัญญาซื้อขายพันธบัตรค่าเงินต้นต่อระยะเวลา 10 ปีของสหรัฐอเมริกา (10-Year Treasury Note) ซึ่งเป็นหนึ่งในสินทรัพย์ที่ใช้ในการประเมินอัตราดอกเบี้ยของสหรัฐอเมริกาในระยะยาว อัตราดอกเบี้ยและดัชนีหุ้นมีความสัมพันธ์กันในบางกรณี ซึ่งอัตราดอกเบี้ยสามารถมีผลต่อผลตอบแทนในการลงทุนในหลักทรัพย์หรือหุ้น นี่คือบางปัจจัยที่มีความสัมพันธ์ระหว่างอัตราดอกเบี้ยกับดัชนีหุ้น:
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - **ผลตอบแทนที่ลงทุน: อัตราดอกเบี้ยมีผลต่อผลตอบแทนที่คาดหวังจากการลงทุนในหลักทรัพย์หรือหุ้น หากอัตราดอกเบี้ยสูงขึ้น อาจส่งผลให้ผลตอบแทนจากการลงทุนในหุ้นลดลง เนื่องจากการลงทุนในหุ้นมีความเสี่ยงสูงกว่าการลงทุนในตราสารหนี้ที่มีอัตราดอกเบี้ยสูง**
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - **ความเคลื่อนไหวของตลาด: อัตราดอกเบี้ยสามารถส่งผลต่อความเคลื่อนไหวของตลาดหุ้น หากอัตราดอกเบี้ยเพิ่มขึ้นอาจส่งผลให้นักลงทุนกลับมาลงทุนในตราสารหนี้แทนการลงทุนในหุ้น ซึ่งอาจทำให้ดัชนีหุ้นลดลง**
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - **สภาวะเศรษฐกิจ: อัตราดอกเบี้ยสามารถสะท้อนสภาวะเศรษฐกิจทั้งในระดับประเทศและระดับโลก หากเศรษฐกิจเจริญเติบโตและเข้มแข็ง อัตราดอกเบี้ยอาจมีแนวโน้มเพิ่มขึ้น และอาจส่งผลให้ดัชนีหุ้นเพิ่มขึ้นด้วยผลกระทบจากเหตุการณ์ทางเศรษฐกิจและการเมือง: เหตุการณ์ทางเศรษฐกิจและการเมือง เช่น นโยบายการเงินของธนาคารกลาง นโยบายการเงินระหว่างประเทศ ข่าวสารทางเศรษฐกิจ หรือเหตุการณ์ทางการเมืองสำคัญ อาจมีผลต่ออัตราดอกเบี้ยและส่งผลต่อดัชนีหุ้น**
# <br>
#
# - ### CBOE Volatility Index (VIX)
# #### &nbsp;&nbsp;Volatility Index หรือ (VIX) คือดัชนีซึ่งคำนวณโดยตลาดซื้อขายอนุพันธ์ Chicago Board Options Exchange  ซึ่ง CBOE Volatility Index เป็นดัชนีที่วัดและติดตามความผันผวนในตลาดหุ้นในระดับสัมพันธ์ของตลาดทางการเงินในสหรัฐอเมริกา รูปแบบการคำนวณของ VIX มีความเชื่อมโยงกับราคาตัวเลือกซื้อขายตัวเลือกในตลาดหุ้น ทำให้เป็นตัวบ่งชี้ระดับความเสี่ยงและความเคลื่อนไหวในตลาดในอนาคต
#
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - **VIX ช่วยในการวัดความเปลี่ยนแปลงของตลาดหุ้น โดยเฉพาะในระยะเวลาที่มีความผันผวนมาก ซึ่งสามารถใช้ในการประมาณการความเสี่ยงและความเปลี่ยนแปลงในตลาดที่จะเกิดขึ้นในอนาคต**
#
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - **VIX เป็นดัชนีที่มีค่าระหว่าง 0 ถึง 100 โดยค่าที่ต่ำกว่า 20 ถือว่าตลาดนิ่งและคล่องตัว ในขณะที่ค่าที่สูงกว่า 20 แสดงถึงความเปลี่ยนแปลงและความผันผวนในตลาดที่เพิ่มขึ้น**
#
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - **VIX มักถูกใช้เป็นตัวบ่งชี้ของความเสี่ยงในตลาดทางการเงิน และใช้ในการวิเคราะห์และตัดสินใจในการลงทุน เช่น การปรับสัดส่วนการลงทุน การจัดการความเสี่ยง หรือการวางแผนการลงทุนในอนาคต**
# <br>
#
# - ### Vanguard Short-Term Inflation-Protected Securities Index Fund
# #### &nbsp;&nbsp;Vanguard Short-Term Inflation-Protected Securities Index Fund (VITP) เป็นกองทุนรวมที่จัดการโดย Vanguard ซึ่งเป็นบริษัทลงทุนที่มีชื่อเสียง กองทุนนี้เน้นการลงทุนในตราสารหนี้ที่ป้องกันการเสื่อมค่าจากการเงินและเสื่อมค่าจากการเพิ่มขึ้นของราคาในอนาคต กลไกที่ใช้ในการป้องกันการเสื่อมค่าคือการลงทุนในพันธบัตรค่าเงินต้นที่เชื่อมโยงกับอัตราการเสื่อมค่าของราคาในตลาด &nbsp;&nbsp; VITP มุ่งเน้นการลงทุนในตราสารหนี้ที่มีระยะเวลาสั้น ๆ โดยทั่วไปเป็นพันธบัตรค่าเงินต้นที่มีกำหนดคืนที่เปลี่ยนแปลงตามอัตราการเสื่อมค่าของราคา (inflation) ดังนั้น การลงทุนใน VITP อาจช่วยให้นักลงทุนปกป้องตนเองจากการเสื่อมค่าในการเงินและความเพิ่มขึ้นของราคาในระยะสั้น ๆ &nbsp;&nbsp; การลงทุนใน VITP สามารถช่วยให้นักลงทุนหากำไรจากดอกเบี้ยตราสารหนี้ที่ปรับตามอัตราการเสื่อมค่าของราคา นอกจากนี้ ค่าธรรมเนียมจัดการของ VITP มีแนวโน้มจะต่ำกว่ากองทุนที่มีการจัดการอื่น ๆ ซึ่งช่วยเพิ่มผลตอบแทนในการลงทุน &nbsp;&nbsp; อย่างไรก็ตาม การลงทุนในกองทุนรวมเสมอมีความเสี่ยง ผลตอบแทนของ VITP สามารถขึ้นอยู่กับสถานการณ์ตลาดและอัตราเปลี่ยนแปลงของราคา การอ่านและศึกษาข้อมูลเกี่ยวกับกองทุนก่อนการลงทุนจึงเป็นสิ่งสำคัญเพื่อให้คุณทำการตัดสินใจที่มีความรับผิดชอบ
# <br>
#
# - ### U.S. Treasury Bond Futures
# #### &nbsp;&nbsp; U.S. Treasury Bond Futures คือสัญญาซื้อขายล่วงหน้าสำหรับพันธบัตรค่าเงินต้นของรัฐบาลสหรัฐอเมริกา (U.S. Treasury Bonds) ในตลาดฟิวเจอร์ส การซื้อขายฟิวเจอร์สเป็นการซื้อขายในสัญญาซึ่งกำหนดให้ซื้อหรือขายพันธบัตรค่าเงินต้นในวันที่กำหนดล่วงหน้า โดยมีราคาและเงื่อนไขการซื้อขายที่ระบุไว้ในสัญญา &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; U.S. Treasury Bond Futures ถูกใช้เป็นเครื่องมือในการป้องกันความเสี่ยงและการซื้อขายของนักลงทุน โดยเฉพาะอย่างยิ่งในการบริหารจัดการความเสี่ยงในอัตราดอกเบี้ย นักลงทุนที่มีผลกระทบต่อการเปลี่ยนแปลงของอัตราดอกเบี้ยสามารถใช้ U.S. Treasury Bond Futures เพื่อป้องกันความเสี่ยงจากการเพิ่มขึ้นหรือลดลงของอัตราดอกเบี้ย &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; การซื้อขาย U.S. Treasury Bond Futures ในตลาดฟิวเจอร์สมักเกิดขึ้นในการซื้อขายหลักทรัพย์ทางการเงินอื่น ๆ ซึ่งสามารถทำได้ผ่านบริษัทหลักทรัพย์ที่มีความเชี่ยวชาญในการซื้อขายฟิวเจอร์ส การซื้อขายในตลาดฟิวเจอร์สอาจมีความซับซ้อนและมีความเสี่ยง นักลงทุนควรทำความเข้าใจเงื่อนไขและความเสี่ยงที่เกี่ยวข้องกับการลงทุนในฟิวเจอร์สก่อนการเข้าร่วมซื้อขาย
# <br>

# %% [markdown]
# ## **Independent Variable**
# - ### **Open** &nbsp;&nbsp; คือราคาในการเริ่มต้นการซื้อขายหุ้นในแต่ละวัน หรือเป็นราคาที่สัญญาณหุ้นถูกทำการซื้อหรือขายเป็นครั้งแรกในแต่ละวัน การรู้ค่า "Open" ช่วยให้นักลงทุนทราบถึงแนวโน้มเบื้องต้นของการขยับของตลาดในแต่ละวัน
#
# - ### **Volume** &nbsp;&nbsp; รายงานถึงปริมาณการซื้อขายของหุ้นในระยะเวลาที่กำหนด ปริมาณการซื้อขายแสดงถึงความสนใจของตลาดและแรงจูงใจในการซื้อหรือขายหุ้น การวิเคราะห์ปริมาณการซื้อขายสามารถช่วยนักลงทุนตีความความเป็นไปได้ของการขยับของราคา
# - ### **High** &nbsp;&nbsp; เป็นราคาสูงสุดที่หุ้นถูกซื้อหรือขายในระยะเวลาที่กำหนด, เช่น ในหนึ่งวัน การรู้ค่า "High" ช่วยให้นักลงทุนเข้าใจถึงแนวโน้มการขยับของราคาหุ้นในแต่ละวันที่สูงที่สุด
# - ### **Low** &nbsp;&nbsp; เป็นราคาต่ำสุดที่หุ้นถูกซื้อหรือขายในระยะเวลาที่กำหนด การรู้ค่า "Low" ช่วยให้นักลงทุนทราบถึงระดับราคาที่ตลาดเห็นว่าเป็นจุดที่น่าสนใจในการซื้อในแต่ละวัน
# <br>
#
# ## **Dependent Variable**
# - ### **Adj Close (Adjusted Close)** &nbsp;&nbsp;คือราคาปิดหลังจากปรับเพื่อคำนึงถึงการแบ่งหุ้น, เงินปันผล, หรือรายการปรับปรุงอื่น ๆ การใช้ราคาปิดที่ปรับแก้แล้วช่วยให้นักลงทุนเข้าใจภาพรวมที่แท้จริงของการขยับของราคาหุ้นในระยะยาว

# %% [markdown]
# <br>
#
# ### **ในโปรเจคนี้มีข้อกำหนดที่ว่าข้อมูลที่ใช้ในการวิเคราะห์ต้องเป็นข้อมูลที่อยู่ภายในช่วงเวลาที่กำหนดของดัชนีที่ระบุไว้ โดยสิ้นสุดล่าสุดคือข้อมูลย้อนหลัง 2 ปี จากวันปัจจุบัน และหน่วยระยะเวลาที่ใช้เป็นปัจจัยในการวัดผลคือ " 1วัน "**
# <br>

# %% [markdown]
# ## Import Libary

# %%
#!pip install yfinance plotly
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats

import yfinance as yf
import plotly.graph_objects as go
import plotly.express as px

from sklearn import metrics
import tensorflow as tf

# %% [markdown]
# ## Import Function

# %%
import plotly.graph_objects as go

def TimeSeriesPlot(train, test, y_pred):

    compare_score = test.copy()
    compare_score['AdjClose_Pred'] = y_pred

    # Given you don't have 'Open' columns in your data, we'll skip the Candlestick plot for now.
    # Creating a Scatter plot for the training data
    fig = go.Figure(data=[go.Candlestick(x=train.index,
                    open=train['S&P_AdjClose'],  # Use AdjClose as Open for the sake of visualization
                    high=train['S&P_High'],
                    low=train['S&P_Low'],
                    close=train['S&P_AdjClose'],
                    name='Training Data')])


    fig.add_trace(go.Candlestick(x=test.index,
                    open=test['S&P_AdjClose'],  # Use AdjClose as Open for the sake of visualization
                    high=test['S&P_High'],
                    low=test['S&P_Low'],
                    close=test['S&P_AdjClose'],
                    name='Training Data'))

    # Scatter plot for actual forward test data
    fig.add_trace(go.Scatter(x=test.index,
                    y=test['S&P_AdjClose'],
                    mode='lines',
                    line=dict(color='black'),
                    name='Actual Forward Test Data'))

    # Scatter plot for predicted forward test data
    fig.add_trace(go.Scatter(x=test.index,
                    y=compare_score['AdjClose_Pred'],
                    mode='lines',
                    line=dict(color='orange'),
                    name='Predicted Forward Test Data'))

    fig.update_layout(
        autosize=False,
        width=1800,
        height=900,
    )

    fig.show()
#Example Use : TimeSeriesPlot(train, test, y_pred)

# %%
def TimeSeriesplot(train, test, y_pred):
    ''' DataFrame จำเป็นจะต้องเรียงวันที่จากน้อยไปมากมาแล้ว และ ถูกจัดเรียง Date เป็น index ไม่ใช่ column '''
    ## train   เป็น data frame ของชุด train เต็มชุด
    ## test    เป็น data frame ของชุด test  เต็มชุด
    ## y_pred  มาจากการพยากรณ์ของ model

    compare_score = test.copy()
    compare_score['AdjClose_Pred'] = y_pred
    compare_score.head(50)


    # สร้างกราฟแท่งเทียนสำหรับช่วงฝึกฝน
    fig = go.Figure(data=[go.Candlestick(x=train.index,
                    open=train['Open'],
                    high=train['High'],
                    low=train['Low'],
                    close=train['AdjClose'],
                    name='Training Data')])

    # สร้างกราฟแท่งเทียนสำหรับช่วงทดสอบ (ข้อมูลจริง)
    fig.add_trace(go.Candlestick(x=test.index,
                    open=test['Open'],
                    high=test['High'],
                    low=test['Low'],
                    close=test['AdjClose'],
                    name='Actual Foward Test Data'))
    # สร้างกราฟเส้นสำหรับช่วงทดสอบ (ข้อมูลจริง)
    fig.add_trace(go.Scatter(x=test.index,
                    y=test['AdjClose'],
                    mode='lines',
                    line=dict(color='black'),
                    name='Actual Foward Test Data'))
    # สร้างกราฟเส้นสำหรับช่วงทดสอบ (ข้อมูลที่ทำนาย)
    fig.add_trace(go.Scatter(x=test.index,
                    y=compare_score['AdjClose_Pred'],
                    mode='lines',
                    line=dict(color='orange'),
                    name='Predicted Foward Test Data'))

    fig.update_layout(
        autosize=False,
        width=1800,  # ลดความกว้าง
        height=900,  # เพิ่มความสูง
    )

    fig.show()

# TimeSeriesPlot(train, test, y_pred)

# %% [markdown]
# ## Data Selection

# %% [markdown]
# #### S&P 500 Index

# %%
# ดึงข้อมูล S&P500 ระหว่างวันที่ 1 มกราคม 2022 ถึงวันที่ 1 มกราคม 2023
data_SP = yf.download('^GSPC', start="2021-05-01", end="2023-05-01")
data_SP = data_SP[['Open', 'High', 'Low', 'Adj Close', 'Volume']]
data_SP = data_SP.rename(columns={'Adj Close':'AdjClose'})


# สร้างกราฟแท่งเทียนด้วย Plotly
fig = go.Figure(data=[go.Candlestick(x=data_SP.index,
                open=data_SP['Open'],
                high=data_SP['High'],
                low=data_SP['Low'],
                close=data_SP['AdjClose'])])

# ปรับขนาดและรูปร่างของกราฟ
fig.update_layout(
    autosize=False,
    width=1800,  # ลดความกว้าง
    height=900,  # เพิ่มความสูง
)

fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### S&P 500 Index with other 7 Index

# %%
# Specified tickers
index_tickers = ['^TNX', '^VIX', 'CL=F', 'GC=F', '^GSPC', '^TYX', 'VCSH']

# The names for each ticker for better clarity
index_names = {
    '^TNX': '10 Year Bond',
    '^VIX': 'CBOE_Volatility',
    'CL=F': 'Crude_Oil',
    'GC=F': 'Gold',
    '^GSPC': 'S&P',
    '^TYX': 'U.S._Treasury_Bond',
    'VCSH': 'Vanguard_short_term'
}

# Fetch data
data = {}
for ticker in index_tickers:
    ticker_data = yf.download(ticker, start="2021-05-01", end="2023-05-01")

    # Keeping only the desired columns
    ticker_data = ticker_data[['High', 'Low', 'Volume', 'Adj Close']]

    # Renaming 'Adj Close' to 'AdjClose'
    ticker_data = ticker_data.rename(columns={'Adj Close': 'AdjClose'})

    # Append the ticker's name (from the index_names dictionary) as a prefix to each column name for clarity
    ticker_data.columns = [f"{index_names[ticker]}_{col}" for col in ticker_data.columns]

    data[ticker] = ticker_data

# Combining all DataFrames into one
data = pd.concat(data.values(), axis=1)

# Dropping unwanted volume columns for '^TNX' and '^VIX'
data = data.drop(columns=['10 Year Bond_Volume', 'CBOE_Volatility_Volume','U.S._Treasury_Bond_Volume'])

# สร้างกราฟแท่งเทียนด้วย Plotly
fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['S&P_AdjClose'],  # Use AdjClose as Open for the sake of visualization
                high=data['S&P_High'],
                low=data['S&P_Low'],
                close=data['S&P_AdjClose'],
                name='Training Data')])

# ปรับขนาดและรูปร่างของกราฟ
fig.update_layout(
    autosize=False,
    width=1900,  # ลดความกว้าง
    height=900,  # เพิ่มความสูง
)

fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Data set

# %%
data
# Out:
#             10 Year Bond_High  10 Year Bond_Low  10 Year Bond_AdjClose  \
# Date
# 2021-05-03              1.651             1.578                  1.607
# 2021-05-04              1.603             1.557                  1.592
# 2021-05-05              1.626             1.582                  1.584
# 2021-05-06              1.591             1.557                  1.561
# 2021-05-07              1.584             1.471                  1.577
# ...                       ...               ...                    ...
# 2023-04-24              3.545             3.505                  3.515
# 2023-04-25              3.447             3.379                  3.396
# 2023-04-26              3.458             3.375                  3.432
# 2023-04-27              3.532             3.447                  3.528
# 2023-04-28              3.494             3.435                  3.452
#
#             CBOE_Volatility_High  CBOE_Volatility_Low  \
# Date
# ...

# %% [markdown]
# ### Examine Data Type Attributes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 502 entries, 2021-05-03 to 2023-04-28
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   10 Year Bond_High             502 non-null    float64
#  1   10 Year Bond_Low              502 non-null    float64
#  2   10 Year Bond_AdjClose         502 non-null    float64
#  3   CBOE_Volatility_High          502 non-null    float64
#  4   CBOE_Volatility_Low           502 non-null    float64
#  5   CBOE_Volatility_AdjClose      502 non-null    float64
#  6   Crude_Oil_High                502 non-null    float64
#  7   Crude_Oil_Low                 502 non-null    float64
#  8   Crude_Oil_Volume              502 non-null    int64
#  9   Crude_Oil_AdjClose            502 non-null    float64
#  10  Gold_High                     502 non-null    float64
#  11  Gold_Low                      502 non-null    float64
# ...

# %% [markdown]
# ### Assessing the Presence of Null or Missing Values

# %%
data.isna().sum()
# Out:
# 10 Year Bond_High               0
# 10 Year Bond_Low                0
# 10 Year Bond_AdjClose           0
# CBOE_Volatility_High            0
# CBOE_Volatility_Low             0
# CBOE_Volatility_AdjClose        0
# Crude_Oil_High                  0
# Crude_Oil_Low                   0
# Crude_Oil_Volume                0
# Crude_Oil_AdjClose              0
# Gold_High                       0
# Gold_Low                        0
# Gold_Volume                     0
# Gold_AdjClose                   0
# S&P_High                        0
# S&P_Low                         0
# S&P_Volume                      0
# S&P_AdjClose                    0
# U.S._Treasury_Bond_High         0
# U.S._Treasury_Bond_Low          0
# U.S._Treasury_Bond_AdjClose     0
# Vanguard_short_term_High        0
# Vanguard_short_term_Low         0
# Vanguard_short_term_Volume      0
# Vanguard_short_term_AdjClose    0
# dtype: int64

# %% [markdown]
# ### Observing the Trading Volume

# %%
data[['Crude_Oil_Volume','Gold_Volume','S&P_Volume','Vanguard_short_term_Volume']]
# Out:
#             Crude_Oil_Volume  Gold_Volume  S&P_Volume  \
# Date
# 2021-05-03            285969           18  4070220000
# 2021-05-04            370208          182  4452460000
# 2021-05-05            460066           57  4230920000
# 2021-05-06            389214           13  4511000000
# 2021-05-07            431417            2  4016080000
# ...                      ...          ...         ...
# 2023-04-24            306720          145  3290940000
# 2023-04-25            361646          306  3978640000
# 2023-04-26            497778          615  3837030000
# 2023-04-27            345880          355  3750550000
# 2023-04-28            328399          152  4087800000
#
#             Vanguard_short_term_Volume
# Date
# 2021-05-03                     5225800
# 2021-05-04                     3696200
# 2021-05-05                     3548900
# 2021-05-06                     3410200
# 2021-05-07                     3176100
# ...                                ...
# ...

# %% [markdown]
# ## Validating Dataset Partitioning for Comparative Analysis on the Same Date Period
# <br>
#
#
# ### Full Datasets

# %%
data
# Out:
#             10 Year Bond_High  10 Year Bond_Low  10 Year Bond_AdjClose  \
# Date
# 2021-05-03              1.651             1.578                  1.607
# 2021-05-04              1.603             1.557                  1.592
# 2021-05-05              1.626             1.582                  1.584
# 2021-05-06              1.591             1.557                  1.561
# 2021-05-07              1.584             1.471                  1.577
# ...                       ...               ...                    ...
# 2023-04-24              3.545             3.505                  3.515
# 2023-04-25              3.447             3.379                  3.396
# 2023-04-26              3.458             3.375                  3.432
# 2023-04-27              3.532             3.447                  3.528
# 2023-04-28              3.494             3.435                  3.452
#
#             CBOE_Volatility_High  CBOE_Volatility_Low  \
# Date
# ...

# %% [markdown]
# ### Only S&P 500

# %%
data_SP
# Out:
#                    Open         High          Low     AdjClose      Volume
# Date
# 2021-05-03  4191.979980  4209.390137  4188.029785  4192.660156  4070220000
# 2021-05-04  4179.040039  4179.040039  4128.589844  4164.660156  4452460000
# 2021-05-05  4177.060059  4187.720215  4160.939941  4167.589844  4230920000
# 2021-05-06  4169.140137  4202.700195  4147.330078  4201.620117  4511000000
# 2021-05-07  4210.339844  4238.040039  4201.640137  4232.600098  4016080000
# ...                 ...          ...          ...          ...         ...
# 2023-04-24  4132.069824  4142.410156  4117.770020  4137.040039  3290940000
# 2023-04-25  4126.430176  4126.430176  4071.379883  4071.629883  3978640000
# 2023-04-26  4087.780029  4089.669922  4049.350098  4055.989990  3837030000
# 2023-04-27  4075.290039  4138.240234  4075.290039  4135.350098  3750550000
# 2023-04-28  4129.629883  4170.060059  4127.180176  4169.479980  4087800000
#
# [502 rows x 5 columns]

# %% [markdown]
# <br>
#
# ## Correlation Analysis

# %%
_ , ax = plt.subplots(figsize=(15,8))
corr_df_1 = data.iloc[:,:len(data.columns)//2]
corr_df_1['S&P_AdjClose'] = data['S&P_AdjClose']
sns.heatmap(corr_df_1.corr(method='pearson'),annot=True,ax=ax,cmap='BuPu')
# Out:
# <Axes: >

# %%
_ , ax = plt.subplots(figsize=(15,8))
corr_df_2 = data.iloc[:,len(data.columns)//2:]
corr_df_2['S&P_AdjClose'] = data['S&P_AdjClose']
sns.heatmap(corr_df_2.corr(method='pearson'),annot=True,ax=ax,cmap='BuPu')
# Out:
# <Axes: >

# %% [markdown]
# ### Setting Training Set at 80% and Forward Testing Set at 20%

# %%
train_size = int(len(data)-len(data)*0.2)

# %% [markdown]
# ### Specifying the 7 Indices for Analysis

# %%
y = data['S&P_AdjClose']
X = data.drop('S&P_AdjClose', axis=1)

# %%
train = data.iloc[:train_size,:]
test = data.iloc[train_size:,:]


X_train = train[X.columns]
X_test = test[X.columns]

y_train = train[['S&P_AdjClose']]
y_test = test[['S&P_AdjClose']]

# %% [markdown]
# ### Only S&P

# %%
y_SP = data_SP['AdjClose']
X_SP = data_SP.drop('AdjClose', axis=1)

# %%
train_SP = data_SP.iloc[:train_size,:]
test_SP = data_SP.iloc[train_size:,:]


X_train_SP = train_SP[X_SP.columns]
X_test_SP = test_SP[X_SP.columns]

y_train_SP = train_SP[['AdjClose']]
y_test_SP = test_SP[['AdjClose']]

# %% [markdown]
# ### Validation of Data Partitioning: Backtest (Training Set) and Forward Test (Test Set with Unseen Data)

# %%
X_train.head(3)
# Out:
#             10 Year Bond_High  10 Year Bond_Low  10 Year Bond_AdjClose  \
# Date
# 2021-05-03              1.651             1.578                  1.607
# 2021-05-04              1.603             1.557                  1.592
# 2021-05-05              1.626             1.582                  1.584
#
#             CBOE_Volatility_High  CBOE_Volatility_Low  \
# Date
# 2021-05-03             19.120001            17.799999
# 2021-05-04             21.850000            18.110001
# 2021-05-05             19.580000            17.889999
#
#             CBOE_Volatility_AdjClose  Crude_Oil_High  Crude_Oil_Low  \
# Date
# 2021-05-03                 18.309999       64.680000      62.910000
# 2021-05-04                 19.480000       66.190002      64.290001
# 2021-05-05                 19.150000       66.760002      64.919998
#
#             Crude_Oil_Volume  Crude_Oil_AdjClose  ...     S&P_High  \
# Date                                              ...
# ...

# %%
X_train_SP.head(3)
# Out:
#                    Open         High          Low      Volume
# Date
# 2021-05-03  4191.979980  4209.390137  4188.029785  4070220000
# 2021-05-04  4179.040039  4179.040039  4128.589844  4452460000
# 2021-05-05  4177.060059  4187.720215  4160.939941  4230920000

# %%
'S&P_AdjClose' in X_train.columns
# Out:
# False

# %%
'S&P_AdjClose' in X_test.columns
# Out:
# False

# %%
y_train.head(3)
# Out:
#             S&P_AdjClose
# Date
# 2021-05-03   4192.660156
# 2021-05-04   4164.660156
# 2021-05-05   4167.589844

# %%
y_test.head(3)
# Out:
#             S&P_AdjClose
# Date
# 2022-12-02   4071.699951
# 2022-12-05   3998.840088
# 2022-12-06   3941.260010

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Compare Model Evaluation

# %% [markdown]
# ### Model for Specifying the 7 Indices for Analysis

# %%
from sklearn.linear_model import Ridge

# %%
lr = Ridge()

# %%
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=2.41468e-21): result may not be accurate.
# Ridge()

# %%
lr.score(X_test,y_test)
# Out:
# 0.9142368335460188

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ## Model for Only S&P

# %%
lr_sp = Ridge()

# %%
lr_sp.fit(X_train_SP,y_train_SP)
# Out:
# Ridge()

# %%
lr_sp.score(X_test_SP,y_test_SP)
# Out:
# 0.9792070558510293

# %%
y_pred_SP = lr_sp.predict(X_test_SP)

# %% [markdown]
# <br>
# <br>
# <br>
#
# ### Upon analyzing the dataset using all 7 indices, it was observed that the R2 Score was lower than when analyzing solely with the S&P 500 index. Hence, the model was further subjected to feature importance techniques to scrutinize and select significant coefficients of independent variables.
# <br>
# <br>

# %%
np.round(lr.coef_,3)
# Out:
# array([[  6.614,   3.488,  -6.811,   8.229,  10.931, -20.967,   0.29 ,
#          -1.038,  -0.   ,   0.634,   0.052,   0.198,   0.   ,  -0.225,
#           0.622,   0.348,   0.   ,  -3.176,  -2.773,  -5.217,  -6.692,
#          -8.88 ,   0.   ,  20.127]])

# %%
lr.feature_names_in_
# Out:
# array(['10 Year Bond_High', '10 Year Bond_Low', '10 Year Bond_AdjClose',
#        'CBOE_Volatility_High', 'CBOE_Volatility_Low',
#        'CBOE_Volatility_AdjClose', 'Crude_Oil_High', 'Crude_Oil_Low',
#        'Crude_Oil_Volume', 'Crude_Oil_AdjClose', 'Gold_High', 'Gold_Low',
#        'Gold_Volume', 'Gold_AdjClose', 'S&P_High', 'S&P_Low',
#        'S&P_Volume', 'U.S._Treasury_Bond_High', 'U.S._Treasury_Bond_Low',
#        'U.S._Treasury_Bond_AdjClose', 'Vanguard_short_term_High',
#        'Vanguard_short_term_Low', 'Vanguard_short_term_Volume',
#        'Vanguard_short_term_AdjClose'], dtype=object)

# %%
import plotly.graph_objects as go

feature_weights = pd.DataFrame({
    'Weight': np.round(lr.coef_.squeeze(), 3)
}, index=lr.feature_names_in_)

sorted_weights = feature_weights.sort_values(by='Weight', ascending=False)

# Conditionally color bars based on the Weight value
colors = ['#FF761D' if -4 <= val <= 4 else '#695BFD' for val in sorted_weights['Weight']]

# Plotting using plotly.graph_objects
fig = go.Figure(go.Bar(
    x=sorted_weights['Weight'],
    y=sorted_weights.index,
    orientation='h',
    marker_color=colors
))

fig.update_layout(title="Feature Weights", autosize=False, width=1700, height=900)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
selected_columns = sorted_weights[~sorted_weights['Weight'].between(-4, 4)].index.tolist()
selected_columns.append('S&P_AdjClose')
selected_columns.append('S&P_Low')
selected_columns.append('S&P_High')
selected_columns
# Out:
# ['Vanguard_short_term_AdjClose',
#  'CBOE_Volatility_Low',
#  'CBOE_Volatility_High',
#  '10 Year Bond_High',
#  'U.S._Treasury_Bond_AdjClose',
#  'Vanguard_short_term_High',
#  '10 Year Bond_AdjClose',
#  'Vanguard_short_term_Low',
#  'CBOE_Volatility_AdjClose',
#  'S&P_AdjClose',
#  'S&P_Low',
#  'S&P_High']

# %% [markdown]
# <br>
#
# ### **&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; It was discovered that the independent variables 'Vanguard_short_term_AdjClose', 'CBOE_Volatility_Low', 'CBOE_Volatility_High', '10 Year Bond_High', 'U.S._Treasury_Bond_AdjClose', 'Vanguard_short_term_High', '10 Year Bond_AdjClose', 'Vanguard_short_term_Low', 'CBOE_Volatility_AdjClose', 'S&P_AdjClose', 'S&P_Low', and 'S&P_High' held significant importance. Their coefficients exhibited prominent magnitudes, both positive and negative, in the linear-based model such as Ridge Regression.**
# <br>
# <br>

# %% [markdown]
# ## Data Preprocessing in Important independent variables group

# %%
data_g2 = data[selected_columns]

# %%
train_size = int(len(data)-len(data)*0.2)

# %%
X = data_g2[selected_columns]
y = data_g2['S&P_AdjClose']

train = data_g2.iloc[:train_size,:]
test = data_g2.iloc[train_size:,:]


X_train = train[X.columns]
X_test = test[X.columns]

y_train = train[['S&P_AdjClose']]
y_test = test[['S&P_AdjClose']]

# %% [markdown]
# <br>
#
# ## Model Creation

# %%
lr = Ridge()

# %% [markdown]
# ### Model Parameter

# %%
lr.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'positive': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.0001}

# %%
lr.fit(X_train,y_train)
# Out:
# Ridge()

# %% [markdown]
# <br>
# <br>
#
# ## **Model Evaluation**

# %%
y_pred = lr.predict(X_test)

# %%
print('R2 Score : ',lr.score(X_test,y_test))
print('Mean Absolute Error : ',np.round(metrics.mean_absolute_error(y_test,y_pred),5))
print('Mean Squared Error  : ',np.round(metrics.mean_squared_error(y_test,y_pred),5))
# Out:
# R2 Score :  0.9999999999964003
# Mean Absolute Error :  0.00016
# Mean Squared Error  :  0.0

# %% [markdown]
# <br>
# <br>
#
# ### Prediction Based on the Feature Importance of the 7 Indices: It can be inferred that the accuracy is close to or approximately 100%

# %%
TimeSeriesPlot(train, test, y_pred)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print('R2 Score : ',lr.score(X_test,y_test))
print('Mean Absolute Error : ',np.round(metrics.mean_absolute_error(y_test,y_pred),5))
print('Mean Squared Error  : ',np.round(metrics.mean_squared_error(y_test,y_pred),5))
# Out:
# R2 Score :  0.9999999999964003
# Mean Absolute Error :  0.00016
# Mean Squared Error  :  0.0

# %%
TimeSeriesplot(train_SP, test_SP, y_pred_SP)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print('R2 Score : ',lr_sp.score(X_test_SP,y_test_SP))
print('Mean Absolute Error : ',np.round(metrics.mean_absolute_error(y_test_SP,y_pred_SP),5))
print('Mean Squared Error  : ',np.round(metrics.mean_squared_error(y_test_SP,y_pred_SP),5))
# Out:
# R2 Score :  0.9792070558510293
# Mean Absolute Error :  11.33043
# Mean Squared Error  :  221.32139

# %% [markdown]
# <br>
# <br>
# <br>
#
# # **Summary**
# ### Utilizing Features for Prediction It is evident that when using data from 'Vanguard_short_term_AdjClose', 'CBOE_Volatility_Low', 'CBOE_Volatility_High', '10 Year Bond_High', 'U.S._Treasury_Bond_AdjClose', 'Vanguard_short_term_High', '10 Year Bond_AdjClose', 'Vanguard_short_term_Low', 'CBOE_Volatility_AdjClose', 'S&P_Low', and 'S&P_High' to forecast 'S&P_AdjClose', the model performs better in comparing actual values to predicted ones than solely considering the basic data of 'Open', 'High', 'Low', and 'Volume' from the S&P index.
